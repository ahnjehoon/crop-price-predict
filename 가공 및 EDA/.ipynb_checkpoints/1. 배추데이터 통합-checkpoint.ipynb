# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rc('font', family='Malgun Gothic')

# %%
df2008 = pd.read_csv("C:/농수산가격데이터/1001배추/2008010120081231.csv")
df2009 = pd.read_csv("C:/농수산가격데이터/1001배추/2009010120091231.csv")
df2010 = pd.read_csv("C:/농수산가격데이터/1001배추/2010010120101231.csv")
df2011 = pd.read_csv("C:/농수산가격데이터/1001배추/2011010120111231.csv")
df2012 = pd.read_csv("C:/농수산가격데이터/1001배추/2012010120121231.csv")
df2013 = pd.read_csv("C:/농수산가격데이터/1001배추/2013010120131231.csv")
df2014 = pd.read_csv("C:/농수산가격데이터/1001배추/2014010120141231.csv")
df2015 = pd.read_csv("C:/농수산가격데이터/1001배추/2015010120151231.csv")
df2016 = pd.read_csv("C:/농수산가격데이터/1001배추/2016010120161231.csv")
df2017 = pd.read_csv("C:/농수산가격데이터/1001배추/2017010120171231.csv")
df2018 = pd.read_csv("C:/농수산가격데이터/1001배추/2018010120181231.csv")
# Out:
# C:\Users\PC\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (16,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\PC\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\PC\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (16,21,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\PC\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = pd.concat((df2008, df2009, df2010, df2011, df2012, df2013, df2014, df2015, df2016, df2017, df2018), axis=0)

# %% [markdown]
# ### 경매 종류 선택 aucsecode-숫자 aucsenm-한글
#
# - 1: 경매
#
# - 2: 정가수의
#
#   - 경쟁계약에 의하지 않고 임의로 상대를 선정하여 계약을 체결하는 것
#
# - 3: 자기계산
#
#   - 가격을 정하고 거래(정가매매)
#       1. 출하자 가격과 수량 정해서 도매법인에게 의견전달
#       2. 도매법인이 여러 구매자(중도매인, 매매참가인)에게 알려줌
#       3. 구매 의향 있는 구매자 등장 시 거래성사
#
# - 4: 매수도매
#
#   - 직접 생산자와 출하약정을 맺고 물량을 구입해 중도매인에게 적정 가격으로 공급하는 제도

# %% [markdown]
# ### 경락일자 delngde
# ### 거래단량 delngprut
# ### 거래량 delngqy

# %% [markdown]
# ### 등급코드 stdqlitynewcode / stdqlitynewnm

# %%
df[['stdqlitynewcode','stdqlitynewnm']].drop_duplicates()
# Out:
#        stdqlitynewcode stdqlitynewnm
# 0                   11             특
# 1                   12             상
# 2                   00           NaN
# 7                   13            보통
# 16                  1Z           무등급
# 88                  15            5등
# 92                  14            4등
# 307                 19            등외
# 9109                17            7등
# 24563               18            8등
# 139089              16            6등
# 328522              1A         유기농산물
# 328761              1D           저농약
# 332364              1C           무농약
# 264706              1B           전환기
# 411491             NaN           NaN
# 53722               1Y            혼합

# %%
f, ax = plt.subplots(figsize=(15, 4))
sns.countplot(df['stdqlitynewnm'])

# %%
f, ax = plt.subplots(figsize=(15, 4))
fig = sns.boxplot(x='stdqlitynewnm', y='sbidpric', data=df)

# %% [markdown]
# ### 품종코드 stdspciesnewcode / stdspciesnewnm
# - 구품종코드 stdspciescode stdspciesnm
# - 품목코드 stdprdlstnewcode / stdprdlstnewnm
# - 구품목코드 stdprdlstnm / stdprdlstcode

# %%
df[['stdspciesnewcode','stdspciesnewnm']].drop_duplicates()
# Out:
#         stdspciesnewcode stdspciesnewnm
# 0                 100199             기타
# 3                 100108       쌈(알배기)배추
# 5                 100104           월동배추
# 13                100102           여름배추
# 32                100109            우거지
# 60                100101            봄배추
# 66                100103       김장(가을)배추
# 100               100105          고냉지배추
# 254               100107          생채용배추
# 692               100106           저장배추
# 716               100110           배추뿌리
# 310564            100111           절임배추
# 259815            100198         배추(수입)
# 56990             100113            배양채
# 63878             100197        우거지(수입)

# %%
f, ax = plt.subplots(figsize=(15, 4))
sns.countplot(df['stdspciesnewnm'])

# %%
f, ax = plt.subplots(figsize=(15, 4))
fig = sns.boxplot(x='stdspciesnewnm', y='sbidpric', data=df)

# %% [markdown]
# ### 산지코드 stdmtcnewcode / stdmtcnewnm
# - 구산지코드 cprmtccode / cprmtcnm

# %%
df[['stdmtcnewcode','stdmtcnewnm']].drop_duplicates()
# Out:
#        stdmtcnewcode stdmtcnewnm
# 0                  0         NaN
# 3              46700   부산광역시 강서구
# 5              50800    경상남도 김해시
# 9              46900   부산광역시 사상구
# 11             38100    경상북도 경주시
# 13             38900    경상북도 영천시
# 16             48000  부산광역시 해운대구
# 24             37800    경상북도 포항시
# 26             41400    대구광역시 북구
# 29             21000   인천광역시 계양구
# 34             61100    광주광역시 북구
# 36             21500   인천광역시 남동구
# 45             21400   인천광역시 부평구
# 52             90500       인천광역시
# 54             31700    충청남도 당진시
# 55               NaN         NaN
# 61             59000    전라남도 해남군
# 116            61900    광주광역시 서구
# 120            34300   대전광역시 대덕구
# 124            35000    대전광역시 중구
# 125            58900    전라남도 진도군
# 126            39600    경상북도 김천시
# 129            33000    충청남도 논산시
# 131            33100    충청남도 부여군
# 139            62300   광주광역시 광산구
# 140            58700    전라남도 목포시
# 142            31200    충청남도 천안시
# 147            28700    충청북도 청주시
# 156            90800     세종특별자치시
# 158            27300    충청북도 충주시
# ...              ...         ...
# 287594         49300   부산광역시 사하구
# 313227         06700   서울특별시 서초구
# 315286         32800    충청남도 계룡시
# 317020         03900   서울특별시 마포구
# 331897         57600    전라남도 구례군
# 333198         48700    부산광역시 동구
# 334373         59200    전라남도 강진군
# 340925         42200   대구광역시 수성구
# 362192         22300    인천광역시 중구
# 367051         48500    부산광역시 남구
# 75873          58100    전라남도 화순군
# 161617         17100     경기도 용인시
# 312939         25000     강원도 양양군
# 314964         02800   서울특별시 성북구
# 327641         08300   서울특별시 구로구
# 301825          3900   서울특별시 마포구
# 344230         800TH          태국
# 351693         12400     경기도 가평군
# 73116          47500   부산광역시 연제구
# 81744          24900     강원도 속초시
# 105857         22200    인천광역시 남구
# 250932         49200    부산광역시 서구
# 386199         17100     경기도 용인시
# 413701         30100         NaN
# 8081           42400    대구광역시 남구
# 280560         44000    울산광역시 동구
# 174409         05000   서울특별시 광진구
# 369074         49200    부산광역시 서구
# 12482          04340   서울특별시 용산구
# 96815          23100   인천광역시 옹진군
#
# [493 rows x 2 columns]

# %%
f, ax = plt.subplots(figsize=(15, 4))
sns.countplot(df.groupby("stdmtcnewcode").filter(lambda x: len(x) > 50000)['stdmtcnewcode'])

# %%
f, ax = plt.subplots(figsize=(15, 4))
sns.countplot(df.groupby("stdmtcnewcode").filter(lambda x: len(x) > 50000)['stdmtcnewnm'])

# %%
f, ax = plt.subplots(figsize=(15, 4))
fig = sns.boxplot(x='stdmtcnewnm', y='sbidpric', data=df)

# %% [markdown]
# ### 단위코드 stdunitnewcode / stdunitnewnm

# %%
df[['stdunitnewcode','stdunitnewnm']].drop_duplicates()
# Out:
#        stdunitnewcode stdunitnewnm
# 0                  12           kg
# 562                13          ton
# 89632              11            g

# %% [markdown]
# ### 시장코드 whsalmrktnewcode / whsalmrktnewnm
# - 구시장코드 whsalmrktcode / whsalmrktnm
# - 가락시장 코드 1005601(신) 110001(구)

# %%
df[['whsalmrktnewcode','whsalmrktnewnm']].drop_duplicates()
# Out:
#         whsalmrktnewcode whsalmrktnewnm
# 0                2058701      목포농산물도매시장
# 3                1046901    부산엄궁농산물도매시장
# 11               1048001    부산반여농산물도매시장
# 26               1041401       대구북부도매시장
# 29               1021501   인천구월농축산물도매시장
# 55               1021401    인천삼산농산물도매시장
# 74               1061101    광주각화농산물도매시장
# 107              1061901   광주서부농수산물도매시장
# 120              1034301   대전오정농수산물도매시장
# 139              1034101   대전노은농수산물도매시장
# 147              1028701     청주농수산물도매시장
# 158              1027301     충주농수산물도매시장
# 160              1031201      천안농산물도매시장
# 178              1055001     전주농수산물도매시장
# 183              1056101      정읍농산물도매시장
# 192              1057901      순천농산물도매시장
# 203              1039301      구미농산물도매시장
# 211              1051102    창원팔용농산물도매시장
# 223              1044701     울산농수산물도매시장
# 254              1051101    창원내서농산물도매시장
# 292              1052601      진주농산물도매시장
# 309              1005601      가락동농수산물시장
# 975              1016301     수원농수산물도매시장
# 985              1013901     안양농수산물도매시장
# 987              1015201     안산농수산물도매시장
# 992              1011901     구리농수산물도매시장
# 1017             1026301      원주농산물도매시장
# 1056             1025401      강릉농산물도매시장
# 2055             1024201     춘천농수산물도매시장
# 2166             1054501     익산농수산물도매시장
# 9773             1007701     강서농수산물도매시장
# 116779           1037801      포항농산물도매시장
# 158675           1036701      안동농산물도매시장
# 102274           2059601      여수농산물도매시장

# %%
f, ax = plt.subplots(figsize=(15, 4))
sns.countplot(df.groupby("whsalmrktnewcode").filter(lambda x: len(x) > 250000)['whsalmrktnewnm'])

# %% [raw]
# # df[(df['whsalmrktnewcode'] == (1041401 or 1048001 or 1005601))]
#
# df = df[(df['whsalmrktnewcode'] == 1005601)]
# df[['sbidpric','aucsecode','aucsenm','delngde','delngprut','delngqy','stdunitnewcode','stdunitnewnm','stdqlitynewcode','stdqlitynewnm','stdspciesnewcode','stdspciesnewnm','stdmtcnewcode','stdmtcnewnm']].to_csv('C:/농수산가격데이터/배추_가락시장.csv', index=False, encoding='utf-8-sig')

# %% [raw]
# 데이터 월단위 가공
# 간단한 모델링
